# %% [markdown]
# # Atividade um

# %% [markdown]
# ## 1. Importe o arquivo alunos.csv e armazene seu conteúdo em um DataFrame Pandas.

# %%
import pandas as pd

url_alunos = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
dados_alunos = pd.read_csv(url_alunos, sep=',')

# %% [markdown]
# ## 2. Visualize as primeiras 7 linhas do DataFrame e as 5 últimas.

# %%
dados_alunos.head(7)
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True
# 5  Bruna     23    NaN     False
# 6   Dara     21    7.0      True

# %% [markdown]
# ## 3. Confira a quantidade de linhas e colunas desse DataFrame.

# %%
dados_alunos.shape
# Out:
# (18, 4)

# %% [markdown]
# ## 4. Explore as colunas do DataFrame e analise os tipos dos dados presentes em cada coluna.

# %%
dados_alunos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nome      18 non-null     object
#  1   Idade     18 non-null     int64
#  2   Notas     12 non-null     float64
#  3   Aprovado  18 non-null     bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 578.0+ bytes

# %% [markdown]
# ## Extra: Calcule algumas estatísticas descritivas básicas dos dados do DataFrame (média, desvio padrão, etc). Dica: pesquise pelo método describe.

# %%
dados_alunos.describe()
# Out:
#            Idade      Notas
# count  18.000000  12.000000
# mean   25.500000   6.800000
# std     6.070662   2.204953
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# # Atividade dois

# %% [markdown]
# ## 1. Calcular a média de quartos por apartamento;

# %%
url_imoveis = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
dados_imoveis = pd.read_csv(url_imoveis, sep=';')

# %%
media_quartos = dados_imoveis['Quartos'].mean(numeric_only=True)

# %%
media_quartos
# Out:
# 1.7713895631067962

# %% [markdown]
# ## 2. Conferir quantos bairros únicos existem na nossa base de dados

# %%
dados_imoveis.Bairro.unique()
dados_imoveis.Bairro.nunique()
# Out:
# 162

# %% [markdown]
# ## 3. Analisar quais bairros possuem a média de valor de aluguel mais elevadas;

# %%
dados_imoveis.Bairro.value_counts()
# Out:
# Barra da Tijuca             6259
# Centro                      3258
# Copacabana                  3186
# Ipanema                     2233
# Recreio dos Bandeirantes    2127
#                             ...
# Cachamorra                     1
# Vasco da Gama                  1
# Cidade de Deus                 1
# Itaguaí                        1
# Sepetiba                       1
# Name: Bairro, Length: 162, dtype: int64

# %%
df_preco_bairro = dados_imoveis.groupby('Bairro')[['Valor']].mean(numeric_only=True)

# %%
df_preco_bairro.sort_values('Valor', ascending=True)
# Out:
#                           Valor
# Bairro
# Senador Camará       635.000000
# Santíssimo           709.090909
# Magalhães Bastos     726.666667
# Turiaçu              733.333333
# Inhoaíba             738.888889
# ...                         ...
# Cidade Nova        88166.692308
# Vasco da Gama     120000.000000
# Caju              120264.782609
# Irajá             154610.470588
# Jacarepaguá       314143.489637
#
# [162 rows x 1 columns]

# %% [markdown]
# ## 4. Criar um gráfico de barras horizontais que apresente os 5 bairros com as médias de valores de aluguel mais elevadas.

# %%
alugueis_mais_caro = df_preco_bairro.sort_values('Valor').tail(5)

# %%
alugueis_mais_caro.plot(kind='barh', figsize=(14, 10), color ='blue')
# Out:
# <Axes: ylabel='Bairro'>

# %% [markdown]
# # Atividade três

# %% [markdown]
# ## 1.  Verifique se a base de dados possui dados nulos e, caso tenha, realize o tratamento desses dados nulos da forma que achar mais coerente com a situação.

# %%
url_dados = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
df_alunos = pd.read_csv(url_dados)

# %%
df_alunos
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %%
df_alunos = df_alunos.fillna(0)
df_alunos
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# ## 2. Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados.

# %%
alunos_para_remover = df_alunos.query('Nome == "Alice" | Nome == "Carlos"').index

# %%
df_alunos.drop(alunos_para_remover, axis=0, inplace=True)

# %%
df_alunos
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# ## 3. Aplique um filtro que selecione apenas os alunos que foram aprovados.

# %%
df_alunos_aprovados = df_alunos['Aprovado'] == True

# %%
df_alunos[df_alunos_aprovados]
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %% [markdown]
# ## 4. Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv".

# %%
df_alunos[df_alunos_aprovados].to_csv('alunos_aprovados.csv', sep=',', index=False)

# %%
pd.read_csv('alunos_aprovados.csv')
# Out:
#         Nome  Idade  Notas  Aprovado
# 0        Ary     20    7.5      True
# 1       Beto     21   10.0      True
# 2       Dara     21    7.0      True
# 3  Sthefanie     26    9.5      True
# 4      Mirla     25    9.0      True
# 5     Mylena     29    7.0      True
# 6      Nadia     34    8.0      True

# %% [markdown]
# ## Extra: Ao conferir as notas dos alunos aprovados, notamos que algumas notas estavam incorretas. As alunas que tiraram nota 7.0, na verdade, tinham um ponto extra que não foi contabilizado. Sendo assim, substitua as notas 7.0 da base de dados por 8.0. Dica: pesquise pelo método replace.

# %%
df_alunos
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %%
notas_para_substituir = df_alunos.query('Notas == 7').index

# %%
df_alunos['Notas'].replace(7, 8, inplace=True)

# %%
df_alunos
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    8.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    8.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# # Atividade quatro

# %% [markdown]
# ## 1. Os alunos participaram de uma atividade extracurricular e ganharam pontos extras. Esses pontos extras correspondem a 40% da nota atual de cada um deles. Com base nisso, crie uma coluna chamada "Pontos_extras" que contenha os pontos extras de cada aluno, ou seja, 40% da nota atual deles.

# %%
df_alunos['Pontos_extras'] = df_alunos['Notas'] * 0.4
df_alunos
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras
# 0         Ary     20    7.5      True            3.0
# 1         Ana     18    0.0     False            0.0
# 2       Cátia     27    2.5     False            1.0
# 3       Denis     18    5.0     False            2.0
# 4        Beto     21   10.0      True            4.0
# 5       Bruna     23    0.0     False            0.0
# 6        Dara     21    8.0      True            3.2
# 9       Vitor     28    0.0     False            0.0
# 10     Daniel     21    0.0     False            0.0
# 11       Igor     24    4.5     False            1.8
# 12  Sthefanie     26    9.5      True            3.8
# 13      Mirla     25    9.0      True            3.6
# 14      Paulo     37    0.0     False            0.0
# 15     Mylena     29    8.0      True            3.2
# 16      Lucas     33    0.0     False            0.0
# 17      Nadia     34    8.0      True            3.2

# %% [markdown]
# ## 2. Crie mais uma coluna, chamada "Notas_finais" que possua as notas de cada aluno somada com os pontos extras.

# %%
df_alunos['Notas_finais'] = df_alunos['Pontos_extras'] + df_alunos['Notas']
df_alunos
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais
# 0         Ary     20    7.5      True            3.0          10.5
# 1         Ana     18    0.0     False            0.0           0.0
# 2       Cátia     27    2.5     False            1.0           3.5
# 3       Denis     18    5.0     False            2.0           7.0
# 4        Beto     21   10.0      True            4.0          14.0
# 5       Bruna     23    0.0     False            0.0           0.0
# 6        Dara     21    8.0      True            3.2          11.2
# 9       Vitor     28    0.0     False            0.0           0.0
# 10     Daniel     21    0.0     False            0.0           0.0
# 11       Igor     24    4.5     False            1.8           6.3
# 12  Sthefanie     26    9.5      True            3.8          13.3
# 13      Mirla     25    9.0      True            3.6          12.6
# 14      Paulo     37    0.0     False            0.0           0.0
# 15     Mylena     29    8.0      True            3.2          11.2
# 16      Lucas     33    0.0     False            0.0           0.0
# 17      Nadia     34    8.0      True            3.2          11.2

# %% [markdown]
# ## 3. Como houve uma pontuação extra, alguns alunos que não tinham sido aprovados antes podem ter sido aprovados agora. Com base nisso, crie uma coluna chamada "Aprovado_final" com os seguintes valores:
# ###     True: caso o aluno esteja aprovado (nota final deve ser maior ou igual a 6);
# ###   False: caso o aluno esteja reprovado (nota final deve ser menor que 6).

# %%
df_alunos['Aprovado_final'] = df_alunos['Notas_finais'].apply(lambda nota: True if nota >= 6 else False)
df_alunos
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais  \
# 0         Ary     20    7.5      True            3.0          10.5
# 1         Ana     18    0.0     False            0.0           0.0
# 2       Cátia     27    2.5     False            1.0           3.5
# 3       Denis     18    5.0     False            2.0           7.0
# 4        Beto     21   10.0      True            4.0          14.0
# 5       Bruna     23    0.0     False            0.0           0.0
# 6        Dara     21    8.0      True            3.2          11.2
# 9       Vitor     28    0.0     False            0.0           0.0
# 10     Daniel     21    0.0     False            0.0           0.0
# 11       Igor     24    4.5     False            1.8           6.3
# 12  Sthefanie     26    9.5      True            3.8          13.3
# 13      Mirla     25    9.0      True            3.6          12.6
# 14      Paulo     37    0.0     False            0.0           0.0
# 15     Mylena     29    8.0      True            3.2          11.2
# 16      Lucas     33    0.0     False            0.0           0.0
# 17      Nadia     34    8.0      True            3.2          11.2
#
#     Aprovado_final
# 0             True
# 1            False
# 2            False
# 3             True
# 4             True
# 5            False
# 6             True
# 9            False
# 10           False
# 11            True
# 12            True
# 13            True
# 14           False
# 15            True
# 16           False
# 17            True

# %% [markdown]
# ## 4 . Faça uma seleção e verifique quais alunos não tinham sido aprovados anteriormente, mas foram aprovados após a soma dos pontos extras.

# %%
alunos_que_passaram_com_pontos_extras = df_alunos.query('Aprovado == False & Aprovado_final == True')
alunos_que_passaram_com_pontos_extras
# Out:
#      Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais  Aprovado_final
# 3   Denis     18    5.0     False            2.0           7.0            True
# 11   Igor     24    4.5     False            1.8           6.3            True
