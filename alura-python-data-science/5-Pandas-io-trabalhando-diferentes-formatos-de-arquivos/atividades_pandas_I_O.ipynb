# %% [markdown]
# # Atividade um

# %% [markdown]
# ## Seu desafio aqui será fazer a leitura desse arquivo utilizando a função read_csv da biblioteca Pandas. Alguns parâmetros devem ser adicionados para que a leitura seja feita corretamente.

# %%
import pandas as pd

# %%
import requests
import chardet
import csv

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/dados_sus.csv'

# %%
response = requests.get(url)

# %%
chardet.detect(response.content)
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
sniffer = csv.Sniffer()

# %%
with open('/content/dados_sus.csv', encoding='ISO-8859-1') as df_dados_sus:
  delimiter = sniffer.sniff(df_dados_sus.read()).delimiter

# %%
delimiter
# Out:
# ';'

# %%
df_dados_sus = pd.read_csv(url, encoding='ISO-8859-1', sep=';', skiprows=[0, 1, 2])

# %%
df_dados_sus
# Out:
#                                  Unidade da Federação      2008/Jan  \
# 0                                            Rondônia    1388528,39
# 1                                                Acre     902416,00
# 2                                            Amazonas    4735529,42
# 3                                             Roraima     657889,53
# 4                                                Pará   18864744,11
# 5                                               Amapá    1120973,34
# 6                                           Tocantins    3441592,69
# 7                                            Maranhão   10723506,39
# 8                                               Piauí    7985142,43
# 9                                               Ceará   15539821,90
# 10                                Rio Grande do Norte    5947814,08
# 11                                            Paraíba   10723002,45
# 12                                         Pernambuco   14393949,89
# ...

# %%
df_dados_sus.drop([27, 28, 29, 30, 31, 32, 33, 34], axis=0, inplace=True)

# %%
df_dados_sus
# Out:
#    Unidade da Federação     2008/Jan      2008/Fev      2008/Mar  \
# 0              Rondônia   1388528,39    2931283,42    1541682,52
# 1                  Acre    902416,00    1497206,26    1794028,48
# 2              Amazonas   4735529,42    7118990,57    8196635,49
# 3               Roraima    657889,53     777939,31     718688,03
# 4                  Pará  18864744,11   19553758,20   21937342,70
# 5                 Amapá   1120973,34    1268740,33     974651,24
# 6             Tocantins   3441592,69    4985688,85    6205612,60
# 7              Maranhão  10723506,39   13559679,41   13985142,36
# 8                 Piauí   7985142,43   10079928,25   10298372,45
# 9                 Ceará  15539821,90   25735101,55   28724625,75
# 10  Rio Grande do Norte   5947814,08    9509755,83   10352238,59
# 11              Paraíba  10723002,45   11386274,47   12053643,87
# 12           Pernambuco  14393949,89   24181400,95   29991302,71
# ...

# %%
# Forma mais enxuta de fazer
df_dados_sus = pd.read_csv(url, encoding='ISO-8859-1', sep=';', skiprows=3, skipfooter=9, engine='python')

# %%
df_dados_sus
# Out:
#    Unidade da Federação      2008/Jan      2008/Fev      2008/Mar  \
# 0              Rondônia    1388528,39    2931283,42    1541682,52
# 1                  Acre     902416,00    1497206,26    1794028,48
# 2              Amazonas    4735529,42    7118990,57    8196635,49
# 3               Roraima     657889,53     777939,31     718688,03
# 4                  Pará   18864744,11   19553758,20   21937342,70
# 5                 Amapá    1120973,34    1268740,33     974651,24
# 6             Tocantins    3441592,69    4985688,85    6205612,60
# 7              Maranhão   10723506,39   13559679,41   13985142,36
# 8                 Piauí    7985142,43   10079928,25   10298372,45
# 9                 Ceará   15539821,90   25735101,55   28724625,75
# 10  Rio Grande do Norte    5947814,08    9509755,83   10352238,59
# 11              Paraíba   10723002,45   11386274,47   12053643,87
# 12           Pernambuco   14393949,89   24181400,95   29991302,71
# ...

# %% [markdown]
# # Atividade dois

# %% [markdown]
# ## Neste desafio, a sua função é efetuar a leitura desse link do Google Planilhas e depois salvar o DataFrame obtido no formato CSV. Pronto(a) para começar?

# %%
import pandas as pd

# %%
sheet_id = '1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw'
url_sheet = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
df_CO2_emission = pd.read_csv(url_sheet)

# %%
df_CO2_emission
# Out:
#      Country Name country_code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 210         Samoa          WSM         East Asia & Pacific
# 211   Yemen, Rep.          YEM  Middle East & North Africa
# 212  South Africa          ZAF          Sub-Saharan Africa
# 213        Zambia          ZMB          Sub-Saharan Africa
# 214      Zimbabwe          ZWE          Sub-Saharan Africa
#
#                              Indicator Name           1990           1991  \
# 0    CO2 emissions (metric tons per capita)            NaN            NaN
# 1    CO2 emissions (metric tons per capita)    191.745.115    167.681.579
# ...

# %%
df_CO2_emission.to_csv('dados_emissão_co2.csv', index=False)

# %%
dados_emissao_co2 = pd.read_csv('/content/dados_emissão_co2.csv')

# %%
dados_emissao_co2
# Out:
#      Country Name country_code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 210         Samoa          WSM         East Asia & Pacific
# 211   Yemen, Rep.          YEM  Middle East & North Africa
# 212  South Africa          ZAF          Sub-Saharan Africa
# 213        Zambia          ZMB          Sub-Saharan Africa
# 214      Zimbabwe          ZWE          Sub-Saharan Africa
#
#                              Indicator Name           1990           1991  \
# 0    CO2 emissions (metric tons per capita)            NaN            NaN
# 1    CO2 emissions (metric tons per capita)    191.745.115    167.681.579
# ...

# %% [markdown]
# # Atividade tres

# %% [markdown]
# ## Este DataFrame possui 6 colunas: genus (gênero), name (nome), id, family (família), order (ordem) e nutritions (nutrições). Note que a coluna nutritions está com todas as informações nutricionais aninhadas. Portanto, os dados precisam ser normalizados.
#
# ## O desafio agora é normalizar esse DataFrame.

# %%
import pandas as pd

# %%
import requests

# %%
import json

# %%
url = 'https://fruityvice.com/api/fruit/all'

# %%
dados_frutas = requests.get(url)

# %%
dados_frutas_txt = json.loads(dados_frutas.text)

# %%
dados_frutas_normalizado = pd.json_normalize(dados_frutas_txt)

# %%
dados_frutas_normalizado
# Out:
#             name  id           family             order         genus  \
# 0      Persimmon  52        Ebenaceae           Rosales     Diospyros
# 1     Strawberry   3         Rosaceae           Rosales      Fragaria
# 2         Banana   1         Musaceae      Zingiberales          Musa
# 3         Tomato   5       Solanaceae         Solanales       Solanum
# 4           Pear   4         Rosaceae           Rosales         Pyrus
# 5         Durian  60        Malvaceae          Malvales         Durio
# 6     Blackberry  64         Rosaceae           Rosales         Rubus
# 7    Lingonberry  65        Ericaceae          Ericales     Vaccinium
# 8           Kiwi  66    Actinidiaceae  Struthioniformes       Apteryx
# 9         Lychee  67      Sapindaceae        Sapindales        Litchi
# 10     Pineapple  10     Bromeliaceae            Poales        Ananas
# 11           Fig  68         Moraceae           Rosales         Ficus
# ...

# %% [markdown]
# # Atividade quatro

# %% [markdown]
# ## Assim como Vanessa, seu desafio é obter um DataFrame da tabela que contém as informações do número de habitantes de cada país.

# %%
import pandas as pd

# %%
df_dados_populacional = pd.read_html('/content/dados_populacional_wikipedia.html')

# %%
df_dados_populacional
# Out:
# [     Unnamed: 0 Posição    País (ou território dependente) Estimativa da ONU  \
#  0           NaN       1                              Índia     1 429 921 746
#  1           NaN       2                              China     1 426 391 281
#  2           NaN       3                     Estados Unidos       339 987 103
#  3           NaN       4                          Indonésia       277 184 719
#  4           NaN       5                          Paquistão       240 215 932
#  ..          ...     ...                                ...               ...
#  245         NaN       –     Ilha de Ascensão (Reino Unido)               806
#  246         NaN     195                           Vaticano               801
#  247         NaN       –  Ilhas Cocos (Keeling) (Austrália)               573
#  248         NaN       –     Tristão da Cunha (Reino Unido)               241
#  249         NaN       –       Ilhas Pitcairn (Reino Unido)                63
#
# ...

# %%
type(df_dados_populacional)
# Out:
# list

# %%
len(df_dados_populacional)
# Out:
# 3

# %%
df_dados_populacional[0]
# Out:
#      Unnamed: 0 Posição    País (ou território dependente) Estimativa da ONU  \
# 0           NaN       1                              Índia     1 429 921 746
# 1           NaN       2                              China     1 426 391 281
# 2           NaN       3                     Estados Unidos       339 987 103
# 3           NaN       4                          Indonésia       277 184 719
# 4           NaN       5                          Paquistão       240 215 932
# ..          ...     ...                                ...               ...
# 245         NaN       –     Ilha de Ascensão (Reino Unido)               806
# 246         NaN     195                           Vaticano               801
# 247         NaN       –  Ilhas Cocos (Keeling) (Austrália)               573
# 248         NaN       –     Tristão da Cunha (Reino Unido)               241
# 249         NaN       –       Ilhas Pitcairn (Reino Unido)                63
#
#      Data      Estimativa Oficial
# ...

# %%
dados_populacional = df_dados_populacional[0]

# %%
dados_populacional.to_csv('dados_populacional.csv', index=False)

# %%
dados_populacional_csv = pd.read_csv('/content/dados_populacional.csv')

# %%
dados_populacional_csv
# Out:
#      Unnamed: 0 Posição    País (ou território dependente) Estimativa da ONU  \
# 0           NaN       1                              Índia     1 429 921 746
# 1           NaN       2                              China     1 426 391 281
# 2           NaN       3                     Estados Unidos       339 987 103
# 3           NaN       4                          Indonésia       277 184 719
# 4           NaN       5                          Paquistão       240 215 932
# ..          ...     ...                                ...               ...
# 245         NaN       –     Ilha de Ascensão (Reino Unido)               806
# 246         NaN     195                           Vaticano               801
# 247         NaN       –  Ilhas Cocos (Keeling) (Austrália)               573
# 248         NaN       –     Tristão da Cunha (Reino Unido)               241
# 249         NaN       –       Ilhas Pitcairn (Reino Unido)                63
#
#      Data      Estimativa Oficial
# ...

# %% [markdown]
# # Atividade cinco

# %% [markdown]
# ## 1. Criar o banco de dados local com a biblioteca SQLAlchemy.

# %%
import pandas as pd
import sqlalchemy

# %%
sqlalchemy.__version__
# Out:
# '1.4.50'

# %%
# !pip install --upgrade 'sqlalchemy<2.0'

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect

# %%
engine = create_engine('sqlite:///:memory:')

# %% [markdown]
# ## 2. Escrever os dados do arquivo CSV neste banco de dados local.

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/clientes_banco.csv'

# %%
df_dados_clientes = pd.read_csv(url)

# %%
df_dados_clientes
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008809     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840104     62      Ensino médio     Divorciado                1
# 438459     6840222     43      Ensino médio       Solteiro                1
# 438460     6841878     22   Ensino superior       Solteiro                1
# 438461     6842765     59      Ensino médio         Casado                2
# 438462     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
df_dados_clientes.to_sql('clientes', engine, index=False)
# Out:
# 438463

# %%
pd.read_sql('clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008809     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840104     62      Ensino médio     Divorciado                1
# 438459     6840222     43      Ensino médio       Solteiro                1
# 438460     6841878     22   Ensino superior       Solteiro                1
# 438461     6842765     59      Ensino médio         Casado                2
# 438462     6842885     51      Ensino médio         Casado                2
#
# ...

# %% [markdown]
# ## 3. Realizar três atualizações no banco de dados:

# %% [markdown]
# ### Atualizar o registro do cliente de ID 6840104 que teve o rendimento anual alterado para 300000.

# %%
query = 'UPDATE clientes SET "Rendimento_anual" = 300000 WHERE ID_Cliente = 6840104'
with engine.connect() as conn:
  conn.execute(query)

# %%
pd.read_sql('clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008809     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840104     62      Ensino médio     Divorciado                1
# 438459     6840222     43      Ensino médio       Solteiro                1
# 438460     6841878     22   Ensino superior       Solteiro                1
# 438461     6842765     59      Ensino médio         Casado                2
# 438462     6842885     51      Ensino médio         Casado                2
#
# ...

# %% [markdown]
# ### Excluir o registro do cliente de ID 5008809, pois essa pessoa não possui mais conta na instituição financeira.

# %%
query = 'DELETE FROM clientes WHERE ID_Cliente = 5008809'
with engine.connect() as conn:
  conn.execute(query)

# %%
pd.read_sql('clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008810     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438457     6840104     62      Ensino médio     Divorciado                1
# 438458     6840222     43      Ensino médio       Solteiro                1
# 438459     6841878     22   Ensino superior       Solteiro                1
# 438460     6842765     59      Ensino médio         Casado                2
# 438461     6842885     51      Ensino médio         Casado                2
#
# ...

# %% [markdown]
# ### Criar um novo registro de cliente seguindo as especificações abaixo:
#
# ### ID_Cliente: 6850985, Idade: 33, Grau_escolaridade: Doutorado, Estado_civil: Solteiro, Tamanho_familia: 1, Categoria_de_renda: Empregado, Ocupacao: TI,  Anos_empregado: 2, Rendimento_anual: 290000, Tem_carro: 0, Moradia: Casa/apartamento próprio

# %%
query = '''INSERT INTO clientes(ID_Cliente, Idade, Grau_escolaridade, Estado_civil, Tamanho_familia, Categoria_de_renda, Ocupacao, Anos_empregado, Rendimento_anual, Tem_carro, Moradia)
VALUES(6850985, 33, "Doutorado", "Solteiro", 1, "Empregado", "TI", 2, 290000, 0, "Casa/apartamento próprio")'''
with engine.connect() as conn:
  conn.execute(query)

# %%
pd.read_sql('clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008810     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840222     43      Ensino médio       Solteiro                1
# 438459     6841878     22   Ensino superior       Solteiro                1
# 438460     6842765     59      Ensino médio         Casado                2
# 438461     6842885     51      Ensino médio         Casado                2
# 438462     6850985     33         Doutorado       Solteiro                1
#
# ...
